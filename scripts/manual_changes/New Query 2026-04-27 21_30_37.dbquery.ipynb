-- %%
ALTER TABLE dev_workspace.bronze.raw_spotify_tracks
ADD COLUMNS (
  _ingested_at TIMESTAMP,
  _source_file STRING
)

UPDATE dev_workspace.bronze.raw_spotify_tracks
SET 
  _ingested_at = current_timestamp(),
  _source_file = 'unknown'
